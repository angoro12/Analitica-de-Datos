# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width = 400> </a>
#
# <h1 align=center><font size = 5>De los Requerimientos a la Recolección</font></h1>

# %% [markdown]
# ## Introducción
#
# Es este laboratorio seguiremos aprendiendo sobre la metodología de la ciencia de datos y nos centraremos en las ases de **Requerimientos de Datos** y **Recolección de Datos**.

# %% [markdown]
# ## Tabla de Contenido
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# 1. [Requerimientos de Datos](#0)<br>
# 2. [Recolección de Datos](#2)<br>
# </div>
# <hr>

# %% [markdown]
# # Requerimientos de Datos <a id="0"></a>

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DS0103EN/labs/images/lab2_fig1_flowchart_data_requirements.png" width=500>

# %% [markdown]
# En los videos aprendimos que el enfoque analítico seleccionado determina los requerimientos de datos. En específico, el método analítico a usarse requerirá cierto contenido de información, formatos y representaciones, guiado por un conocimiento general.

# %% [markdown]
# En el **Laboratorio Del Problema al Enfoque** determinamos que automatizar el proceso de determinar el tipo de cocina de una receta o platillo es potencialmente posible utilizando los ingredientes de la receta o el plato. Para construir el modelo necesitamos una gran cantidad de datos provenientes de distintas cocinas y platillos.

# %% [markdown]
# La identificación de los datos requeridos complementa la fase de requerimientos en la metodología de la ciencia de datos.
#
# * * *

# %% [markdown]
# # Recolección de Datos <a id="2"></a>

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DS0103EN/labs/images/lab2_fig2_flowchart_data_collection.png" width=500>

# %% [markdown]
# En la fase inicial de la recolección de datos, los científicos de datos identifican y recopilan los recursos disponibles. Estos pueden aparecer en forma datos relevantes estructurados, no estructurados y incluso parcialmente estructurados para el dominio del problema.

# %% [markdown]
# #### Web Scraping de Recetas de Cocina en Línea
#
# Los datos se compilaron por el investigador Yong-Yeol Ahn, quien analizo decenas de miles de recetas de comida (cocinas e ingredientes) de tres distintos sitios web llamados:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DS0103EN/labs/images/lab2_fig3_allrecipes.png" width=500>
#
# [www.allrecipes.com](http://www.allrecipes.com?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DS0103EN/labs/images/lab2_fig4_epicurious.png" width=500>
#
# [www.epicurious.com](http://www.epicurious.com?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DS0103EN/labs/images/lab2_fig5_menupan.png" width=500>
#
# [www.menupan.com](http://www.menupan.com?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# Para mas información sobre Yong-Yeol Ahn y su investigación puede consultarse su trabajo en [Flavor Network and the Principles of Food Pairing](http://yongyeol.com/papers/ahn-flavornet-2011.pdf?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# Por suerte no tendremos que efectuar ninguna recolección de datos ya que los que necesitamos para nuestro propósito de entender esta parte ya se encuentran disponibles.

# %% [markdown]
# #### Hemos obtenido y colocado los datos en un servidor de IBM. Descarguémoslos y continuemos revisándolos.

# %% [markdown]
# <strong>Observación Importante:</strong> Por favor ten en cuenta que no se espera que sepas programar en Python. El siguiente código tiene como propósito ilustrar la fase de recolección de datos, así que es comprensible si no entiendes las líneas de código. Habrá un curso completo en esta certificación sobre como programar en Python, <a href="http://cocl.us/PY0101EN_DS0103EN_LAB4_PYTHON_edX">Python for Data Science</a>, con el cual aprenderás como hacerlo si decides terminar esta certificación.

# %% [markdown]
# ### Uso de este cuaderno:
#
# Para ejecutar las siguientes celdas de código, debes pulsar **Shift + Enter** y el código dentro de las celdas será ejecutado.

# %% [markdown]
# Obtener la versión de Python instalada.

# %%
# revisar la versión de Python
# !python -V

# %% [markdown]
# Descarga los datos desde un servidor IBM y guárdalos en un dataframe _pandas_

# %%
import pandas as pd # descargar la librería y guardar los datos en un DataFrame
pd.set_option('display.max_columns', None)

recipes = pd.read_csv("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DS0103EN/labs/data/recipes.csv")

print("Data read into dataframe!") # toma alrededor de 30 segundos

# %% [markdown]
# Muestra las primeras filas.

# %%
recipes.head()

# %% [markdown]
# Obtener el tamaño del DataFrame

# %%
recipes.shape

# %% [markdown]
# Nuestro conjunto de datos consiste en 57,691 recetas. Cada fila representa una receta y por cada receta la cocina a la que pertenece también esta documentada así como si alguno de los 384 ingredientes existe dentro de esa receta, comenzado con las almendras (almonds) y finalizando con el zucchini (calabacín).
#
# * * *

# %% [markdown]
# Ahora que la fase de recolección de datos esta completada normalmente los científicos utilizan estadística descriptiva y técnicas de visualización para comprender mejor los datos y familiarizase con ellos. En esencia, los datos son explorados para:
#
# -   comprender su contenido,
# -   evaluar su calidad,
# -   encontrar algo interesante, y
# -   determinar si es necesario obtener datos adicionales.

# %% [markdown]
# ### ¡Gracias por terminar este laboratorio!
#
# Este cuaderno fue creado por Alex Aklson. Espero que hayas encontrado esta sesión interesante. ¡Por favor contáctame si tienes alguna pregunta!

# %% [markdown]
# Este cuaderno es parte del curso en **edX** llamado _The Data Science Method_. Si tienes acceso a este documento desde fuera del curso, puedes tomarlo en línea haciendo clic [aquí](https://cocl.us/DS0103EN_edX_LAB4).

# %% [markdown]
# <hr>
#
# Copyright © 2020 [IBM Developer Skills Network](https://cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103ES-edX-20127823&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
